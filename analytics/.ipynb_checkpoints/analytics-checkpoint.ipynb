# %% [markdown]
# # Analytics - Product Quality
#
# #### Date: 2020/02
#
# #### SUMMARY:
#
# - This notebook represents the project quality analysis of the date exposed right above.
#
# ### TEAM:
#
# ##### Semester: 2023/01
# ##### Professor: Hilmer Neri
#
# ##### Members:
#
# - Aline Lermen
# - Caio Martins
# - Dafne Moretti
# - João Pedro
# - João Vitor
# - Lucas Gabriel
# - Lucas Lima
# - Eric Camargo
# - Ester Flores
# - Leonardo Ferreira
# - Luana Torres
# - Matheus Ferreira
# - Pablo Guilherme
# - Pedro Izarias
# - Pedro Sena
# - Suzane Duarte

# %% [markdown]
# ### LIBRARIES

# %%
# Deal with data
import pandas as pd
import json
from glob import glob
import os

# Deal with visualization
import seaborn as sns
import matplotlib.pyplot as plt

# Deal with type hints
from typing import List

# Deal with time
import datetime

# %% [markdown]
# ### GRAPH SETTINGS

# %%
# %config InlineBackend.figure_format ='retina'
sns.set(font_scale=1.5)
sns.set_style('darkgrid',
              {'xtick.bottom' : True,
               'ytick.left': True,
               'grid.linestyle':'--',
               'font.monospace': ['Computer Modern Typewriter'],
               'axes.edgecolor' : 'white'})

# %% [markdown]
# ### DATAFRAME SETTINGS

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# #### Replace your semester, project name, repository name, and the programming language extension

# %%
# Set your repo major name here
# Example: fga-eps-mds-2022-1-MeasureSoftGram-
repo_name = 'fga-eps-mds-2023-1-Alectrion-'

# Add your repos here
# Example: 'Front': 'py',
repos_language = {
    'EquipamentApi': 'py',
    'Gateway': 'py',
    'UserAPI': 'ts',
    'FrontEnd': 'py',
}

# %% [markdown]
# ### SonarCloud
# ##### Path to the folder with all your jsons

# %%
# Maybe you should change this path to your own path !!!!! PRESTAR ATENCAO NO PATH

sonar_files = glob('../analytics-raw-data/*.json')

# %% [markdown]
# ## Create DataFrame

# %% [markdown]
# #### Unmarshall json

# %%
def unmarshall(json_path: str) -> dict:
    with open(json_path) as json_file:
        json_obj = json.load(json_file)
    return json_obj

# %% [markdown]
# #### Create a list with all valid columns

# %%
metric_list = ['files',
               'functions',
               'complexity',
               'comment_lines_density',
               'duplicated_lines_density',
               'coverage',
               'ncloc',
               'tests',
               'test_errors',
               'test_failures',
               'test_execution_time',
               'security_rating']

# %% [markdown]
# #### Extract files dataframe out of component dataframe

# %%
def get_files_df(df: pd.DataFrame) -> pd.DataFrame:

    files_df = df[df['qualifier'] == 'FIL']

    files_df = files_df.dropna(subset=['functions', 'complexity','comment_lines_density', 'duplicated_lines_density', 'coverage' ])

    return files_df

# %% [markdown]
# #### Extract directories dataframe out of component dataframe

# %%
def get_dir_df(df: pd.DataFrame) -> pd.DataFrame:
    dirs = df[df["qualifier"] == "DIR"]

    newdf = pd.to_numeric(dirs["tests"])

    max_value_index = newdf.idxmax()

    return dirs.loc[max_value_index]

# %% [markdown]
# #### Extract uts dataframe out of component dataframe

# %%
def get_uts_df(df: pd.DataFrame) -> pd.DataFrame:
    uts_df = df[df['qualifier'] == 'UTS']

    uts_df = uts_df.fillna(0)

    uts_df = uts_df.dropna(subset=['test_execution_time'])

    return uts_df

# %% [markdown]
# #### Generate component dataframe

# %%
def metric_per_file(json_dict: dict) -> List[dict]:
    file_json = []

    for component in json_dict['components']:
        ncloc_value = 0
        for measure in component['measures']:
            if measure['metric'] == 'ncloc':
                ncloc_value = float(measure['value'])
                break

        if (component['qualifier'] == 'FIL' and ncloc_value > 0) \
                or component['qualifier'] == 'DIR' \
                or component['qualifier'] == 'UTS':
            file_json.append(component)

    return file_json


def generate_component_dataframe_data(
        metrics_list: List[str],
        file_component_data: List[dict],
        language_extension: str) -> pd.DataFrame:

    df_columns = metrics_list

    files_df = pd.DataFrame(columns = df_columns)
    dirs_df = pd.DataFrame(columns = df_columns)
    uts_df = pd.DataFrame(columns = df_columns)

    for file in file_component_data:
        try:
                if file['qualifier'] == 'FIL' and file['language'] == language_extension:
                    for measure in file['measures']:
                        files_df.at[file['path'], measure['metric']] = measure['value']

                    files_df['qualifier'] = file['qualifier']

                elif file['qualifier'] == 'DIR':
                    for measure in file['measures']:
                        dirs_df.at[file['path'], measure['metric']] = measure['value']

                    dirs_df['qualifier'] = file['qualifier']

                elif file['qualifier'] == 'UTS':
                    for measure in file['measures']:
                        uts_df.at[file['path'], measure['metric']] = measure['value']

                    uts_df['qualifier'] = file['qualifier']

        except:
            pass

    files_df.reset_index(inplace = True)
    dirs_df.reset_index(inplace = True)
    uts_df.reset_index(inplace = True)

    files_df = files_df.rename({'index': 'path'}, axis=1).drop(['files'], axis=1)
    dirs_df = dirs_df.rename({'index': 'path'}, axis=1).drop(['files'], axis=1)
    uts_df = uts_df.rename({'index': 'path'}, axis=1).drop(['files'], axis=1)

    df = pd.concat([files_df, dirs_df, uts_df], axis=0)

    return df


def create_component_df(json_list):
    df = pd.DataFrame()

    for json_path in json_list:
        file_component = unmarshall(json_path)
        file_component_data = metric_per_file(file_component)

        base_name = os.path.basename(json_path)

        file_component_dataframe = generate_component_dataframe_data(
            metric_list,
            file_component_data,
            language_extension = repos_language[base_name.split("-")[6]])


        file_component_dataframe['filename'] = base_name

        df = pd.concat([df, file_component_dataframe], ignore_index=True)

    aux_df = df['filename'].str.split(r"-(\d+-\d+-\d+-\d+-\d+-\d+)-(.*?).json", expand=True)

    df['repository'] = aux_df[0]
    df['datetime'] = aux_df[1]
    df['version'] = aux_df[2]

    df = df.sort_values(by=['repository', 'datetime'])

    return df

# %%
file_component_df = create_component_df(sonar_files)
file_component_df.repository.unique()
# Out:
#                                                    path functions complexity  \
# 677                                        src/adapters         2          3
# 678                         src/presentation/controller        24         79
# 679                           src/factories/controllers        12         12
# 680                   src/useCases/create-order-service        10         19
# 681                        src/useCases/createEquipment        10         54
# 682                         src/useCases/createMovement        12         32
# 683                                              src/db        46         50
# 684                         src/useCases/deleteMovement         7         12
# 685                                 src/domain/entities         0          0
# 686                                     src/db/entities        28         28
# 687                  src/domain/entities/equipamentEnum         0          0
# 688                       src/db/repositories/equipment         5          7
# 689                            src/repository/equipment         0          0
# 690                             src/presentation/errors         6          7
# 691            src/useCases/create-order-service/errors         8          8
# 692                                       src/factories        24         24
# 693                     src/useCases/find-order-service         3          4
# 694                        src/useCases/findAcquisition         3          4
# 695                              src/useCases/findBrand         3          4
# 696                          src/useCases/findMovements         4         12
# 697                       src/useCases/findOneEquipment         3          4
# 698                               src/useCases/findUnit         3          4
# 699                               src/useCases/FindUnit         3          4
# 700                           src/useCases/getEquipment         2          8
# 701                            src/presentation/helpers         6          8
# 702                         src/db/repositories/history         2          2
# 703                              src/repository/history         0          0
# 704                                     src/middlewares         1          2
# 705                                   src/db/migrations         5          5
# 706                   src/db/repositories/order-service         4          4
# 707                        src/repository/order-service         2          2
# 708                                    src/presentation        37         95
# 709                             src/repository/protocol         0          0
# 710                               src/useCases/protocol         0          0
# 711                          src/presentation/protocols         1          1
# 712                                 src/db/repositories        13         16
# 713                                      src/repository        28         37
# 714                src/domain/entities/serviceOrderEnum         0          0
# 715                                                 src       208        395
# 716                                               tests       NaN        NaN
# 717                src/domain/entities/type-action-enum         0          0
# 718                            src/db/repositories/unit         2          3
# 719                                 src/repository/unit         0          0
# 720                   src/useCases/update-order-service         3         18
# 721                                        src/useCases        66        179
# 722                              src/factories/useCases        12         12
# 723              tests/create-equipment-usecase.spec.ts       NaN        NaN
# 724       tests/create-order-service-controller.spec.ts       NaN        NaN
# 725                  tests/create-order-service.spec.ts       NaN        NaN
# 726             tests/createEquipmentController.spec.ts       NaN        NaN
# 727              tests/createMovementController.spec.ts       NaN        NaN
# 728                 tests/createMovementUseCase.spec.ts       NaN        NaN
# 729              tests/deleteMovementController.spec.ts       NaN        NaN
# 730                 tests/deleteMovementUseCase.spec.ts       NaN        NaN
# 731                   tests/find-orders-service.spec.ts       NaN        NaN
# 732                tests/findAllUnitsController.spec.ts       NaN        NaN
# 733               tests/findMovementsController.spec.ts       NaN        NaN
# 734                  tests/findMovementsUseCase.spec.ts       NaN        NaN
# 735                tests/getEquipmentController.spec.ts       NaN        NaN
# 736                   tests/getEquipmentUseCase.spec.ts       NaN        NaN
# 737       tests/update-order-service-controller.spec.ts       NaN        NaN
# 738                  tests/update-order-service.spec.ts       NaN        NaN
# 186                                        src/adapters         2          3
# 187                         src/presentation/controller        24         79
# 188                           src/factories/controllers        12         12
# 189                   src/useCases/create-order-service        10         19
# 190                        src/useCases/createEquipment        10         54
# 191                         src/useCases/createMovement        12         32
# 192                                              src/db        46         50
# 193                         src/useCases/deleteMovement         7         12
# 194                                 src/domain/entities         0          0
# 195                                     src/db/entities        28         28
# 196                  src/domain/entities/equipamentEnum         0          0
# 197                       src/db/repositories/equipment         5          7
# 198                            src/repository/equipment         0          0
# 199                             src/presentation/errors         6          7
# 200            src/useCases/create-order-service/errors         8          8
# 201                                       src/factories        24         24
# 202                     src/useCases/find-order-service         3          4
# 203                        src/useCases/findAcquisition         3          4
# 204                              src/useCases/findBrand         3          4
# 205                          src/useCases/findMovements         4         12
# 206                       src/useCases/findOneEquipment         3          4
# 207                               src/useCases/findUnit         3          4
# 208                               src/useCases/FindUnit         3          4
# 209                           src/useCases/getEquipment         2          8
# 210                            src/presentation/helpers         6          8
# 211                         src/db/repositories/history         2          2
# 212                              src/repository/history         0          0
# 213                                     src/middlewares         1          2
# 214                                   src/db/migrations         5          5
# 215                   src/db/repositories/order-service         4          4
# 216                        src/repository/order-service         2          2
# 217                                    src/presentation        37         95
# 218                             src/repository/protocol         0          0
# 219                               src/useCases/protocol         0          0
# 220                          src/presentation/protocols         1          1
# 221                                 src/db/repositories        13         16
# 222                                      src/repository        28         37
# 223                src/domain/entities/serviceOrderEnum         0          0
# 224                                                 src       208        395
# 225                                               tests       NaN        NaN
# 226                src/domain/entities/type-action-enum         0          0
# 227                            src/db/repositories/unit         2          3
# 228                                 src/repository/unit         0          0
# 229                   src/useCases/update-order-service         3         18
# 230                                        src/useCases        66        179
# 231                              src/factories/useCases        12         12
# 232              tests/create-equipment-usecase.spec.ts       NaN        NaN
# 233       tests/create-order-service-controller.spec.ts       NaN        NaN
# 234                  tests/create-order-service.spec.ts       NaN        NaN
# 235             tests/createEquipmentController.spec.ts       NaN        NaN
# 236              tests/createMovementController.spec.ts       NaN        NaN
# 237                 tests/createMovementUseCase.spec.ts       NaN        NaN
# 238              tests/deleteMovementController.spec.ts       NaN        NaN
# 239                 tests/deleteMovementUseCase.spec.ts       NaN        NaN
# 240                   tests/find-orders-service.spec.ts       NaN        NaN
# 241                tests/findAllUnitsController.spec.ts       NaN        NaN
# 242               tests/findMovementsController.spec.ts       NaN        NaN
# 243                  tests/findMovementsUseCase.spec.ts       NaN        NaN
# 244                tests/getEquipmentController.spec.ts       NaN        NaN
# 245                   tests/getEquipmentUseCase.spec.ts       NaN        NaN
# 246       tests/update-order-service-controller.spec.ts       NaN        NaN
# 247                  tests/update-order-service.spec.ts       NaN        NaN
# 0                                          src/adapters         2          3
# 1                           src/presentation/controller        24         79
# 2                             src/factories/controllers        12         12
# 3                     src/useCases/create-order-service        10         19
# 4                          src/useCases/createEquipment        10         54
# 5                           src/useCases/createMovement        12         32
# 6                                                src/db        46         50
# 7                           src/useCases/deleteMovement         7         12
# 8                                   src/domain/entities         0          0
# 9                                       src/db/entities        28         28
# 10                   src/domain/entities/equipamentEnum         0          0
# 11                        src/db/repositories/equipment         5          7
# 12                             src/repository/equipment         0          0
# 13                              src/presentation/errors         6          7
# 14             src/useCases/create-order-service/errors         8          8
# 15                                        src/factories        24         24
# 16                      src/useCases/find-order-service         3          4
# 17                         src/useCases/findAcquisition         3          4
# 18                               src/useCases/findBrand         3          4
# 19                           src/useCases/findMovements         4         12
# 20                        src/useCases/findOneEquipment         3          4
# 21                                src/useCases/findUnit         3          4
# 22                                src/useCases/FindUnit         3          4
# 23                            src/useCases/getEquipment         2          8
# 24                             src/presentation/helpers         6          8
# 25                          src/db/repositories/history         2          2
# 26                               src/repository/history         0          0
# 27                                      src/middlewares         1          2
# 28                                    src/db/migrations         5          5
# 29                    src/db/repositories/order-service         4          4
# 30                         src/repository/order-service         2          2
# 31                                     src/presentation        37         95
# 32                              src/repository/protocol         0          0
# 33                                src/useCases/protocol         0          0
# 34                           src/presentation/protocols         1          1
# 35                                  src/db/repositories        13         16
# 36                                       src/repository        28         37
# 37                 src/domain/entities/serviceOrderEnum         0          0
# 38                                                  src       208        395
# 39                                                tests       NaN        NaN
# 40                 src/domain/entities/type-action-enum         0          0
# 41                             src/db/repositories/unit         2          3
# 42                                  src/repository/unit         0          0
# 43                    src/useCases/update-order-service         3         18
# 44                                         src/useCases        66        179
# 45                               src/factories/useCases        12         12
# 46               tests/create-equipment-usecase.spec.ts       NaN        NaN
# 47        tests/create-order-service-controller.spec.ts       NaN        NaN
# 48                   tests/create-order-service.spec.ts       NaN        NaN
# 49              tests/createEquipmentController.spec.ts       NaN        NaN
# 50               tests/createMovementController.spec.ts       NaN        NaN
# 51                  tests/createMovementUseCase.spec.ts       NaN        NaN
# 52               tests/deleteMovementController.spec.ts       NaN        NaN
# 53                  tests/deleteMovementUseCase.spec.ts       NaN        NaN
# 54                    tests/find-orders-service.spec.ts       NaN        NaN
# 55                 tests/findAllUnitsController.spec.ts       NaN        NaN
# 56                tests/findMovementsController.spec.ts       NaN        NaN
# 57                   tests/findMovementsUseCase.spec.ts       NaN        NaN
# 58                 tests/getEquipmentController.spec.ts       NaN        NaN
# 59                    tests/getEquipmentUseCase.spec.ts       NaN        NaN
# 60        tests/update-order-service-controller.spec.ts       NaN        NaN
# 61                   tests/update-order-service.spec.ts       NaN        NaN
# 372                                        src/adapters         2          3
# 373                         src/presentation/controller        24         79
# 374                           src/factories/controllers        12         12
# 375                   src/useCases/create-order-service        10         19
# 376                        src/useCases/createEquipment        10         54
# 377                         src/useCases/createMovement        12         32
# 378                                              src/db        46         50
# 379                         src/useCases/deleteMovement         7         12
# 380                                 src/domain/entities         0          0
# 381                                     src/db/entities        28         28
# 382                  src/domain/entities/equipamentEnum         0          0
# 383                       src/db/repositories/equipment         5          7
# 384                            src/repository/equipment         0          0
# 385                             src/presentation/errors         6          7
# 386            src/useCases/create-order-service/errors         8          8
# 387                                       src/factories        24         24
# 388                     src/useCases/find-order-service         3          4
# 389                        src/useCases/findAcquisition         3          4
# 390                              src/useCases/findBrand         3          4
# 391                          src/useCases/findMovements         4         12
# 392                       src/useCases/findOneEquipment         3          4
# 393                               src/useCases/findUnit         3          4
# 394                               src/useCases/FindUnit         3          4
# 395                           src/useCases/getEquipment         2          8
# 396                            src/presentation/helpers         6          8
# 397                         src/db/repositories/history         2          2
# 398                              src/repository/history         0          0
# 399                                     src/middlewares         1          2
# 400                                   src/db/migrations         5          5
# 401                   src/db/repositories/order-service         4          4
# 402                        src/repository/order-service         2          2
# 403                                    src/presentation        37         95
# 404                             src/repository/protocol         0          0
# 405                               src/useCases/protocol         0          0
# 406                          src/presentation/protocols         1          1
# 407                                 src/db/repositories        13         16
# 408                                      src/repository        28         37
# 409                src/domain/entities/serviceOrderEnum         0          0
# 410                                                 src       208        395
# 411                                               tests       NaN        NaN
# 412                src/domain/entities/type-action-enum         0          0
# 413                            src/db/repositories/unit         2          3
# 414                                 src/repository/unit         0          0
# 415                   src/useCases/update-order-service         3         18
# 416                                        src/useCases        66        179
# 417                              src/factories/useCases        12         12
# 418              tests/create-equipment-usecase.spec.ts       NaN        NaN
# 419       tests/create-order-service-controller.spec.ts       NaN        NaN
# 420                  tests/create-order-service.spec.ts       NaN        NaN
# 421             tests/createEquipmentController.spec.ts       NaN        NaN
# 422              tests/createMovementController.spec.ts       NaN        NaN
# 423                 tests/createMovementUseCase.spec.ts       NaN        NaN
# 424              tests/deleteMovementController.spec.ts       NaN        NaN
# 425                 tests/deleteMovementUseCase.spec.ts       NaN        NaN
# 426                   tests/find-orders-service.spec.ts       NaN        NaN
# 427                tests/findAllUnitsController.spec.ts       NaN        NaN
# 428               tests/findMovementsController.spec.ts       NaN        NaN
# 429                  tests/findMovementsUseCase.spec.ts       NaN        NaN
# 430                tests/getEquipmentController.spec.ts       NaN        NaN
# 431                   tests/getEquipmentUseCase.spec.ts       NaN        NaN
# 432       tests/update-order-service-controller.spec.ts       NaN        NaN
# 433                  tests/update-order-service.spec.ts       NaN        NaN
# 1289                                       src/adapters         2          3
# 1290                        src/presentation/controller        24         79
# 1291                          src/factories/controllers        12         12
# 1292                  src/useCases/create-order-service        10         19
# 1293                       src/useCases/createEquipment        10         54
# 1294                        src/useCases/createMovement        12         32
# 1295                                             src/db        46         50
# 1296                        src/useCases/deleteMovement         7         12
# 1297                                src/domain/entities         0          0
# 1298                                    src/db/entities        28         28
# 1299                 src/domain/entities/equipamentEnum         0          0
# 1300                      src/db/repositories/equipment         5          7
# 1301                           src/repository/equipment         0          0
# 1302                            src/presentation/errors         6          7
# 1303           src/useCases/create-order-service/errors         8          8
# 1304                                      src/factories        24         24
# 1305                    src/useCases/find-order-service         3          4
# 1306                       src/useCases/findAcquisition         3          4
# 1307                             src/useCases/findBrand         3          4
# 1308                         src/useCases/findMovements         4         12
# 1309                      src/useCases/findOneEquipment         3          4
# 1310                              src/useCases/findUnit         3          4
# 1311                              src/useCases/FindUnit         3          4
# 1312                          src/useCases/getEquipment         2          8
# 1313                           src/presentation/helpers         6          8
# 1314                        src/db/repositories/history         2          2
# 1315                             src/repository/history         0          0
# 1316                                    src/middlewares         1          2
# 1317                                  src/db/migrations         5          5
# 1318                  src/db/repositories/order-service         4          4
# 1319                       src/repository/order-service         2          2
# 1320                                   src/presentation        37         95
# 1321                            src/repository/protocol         0          0
# 1322                              src/useCases/protocol         0          0
# 1323                         src/presentation/protocols         1          1
# 1324                                src/db/repositories        13         16
# 1325                                     src/repository        28         37
# 1326               src/domain/entities/serviceOrderEnum         0          0
# 1327                                                src       208        395
# 1328                                              tests       NaN        NaN
# 1329               src/domain/entities/type-action-enum         0          0
# 1330                           src/db/repositories/unit         2          3
# 1331                                src/repository/unit         0          0
# 1332                  src/useCases/update-order-service         3         18
# 1333                                       src/useCases        66        179
# 1334                             src/factories/useCases        12         12
# 1335             tests/create-equipment-usecase.spec.ts       NaN        NaN
# 1336      tests/create-order-service-controller.spec.ts       NaN        NaN
# 1337                 tests/create-order-service.spec.ts       NaN        NaN
# 1338            tests/createEquipmentController.spec.ts       NaN        NaN
# 1339             tests/createMovementController.spec.ts       NaN        NaN
# 1340                tests/createMovementUseCase.spec.ts       NaN        NaN
# 1341             tests/deleteMovementController.spec.ts       NaN        NaN
# 1342                tests/deleteMovementUseCase.spec.ts       NaN        NaN
# 1343                  tests/find-orders-service.spec.ts       NaN        NaN
# 1344               tests/findAllUnitsController.spec.ts       NaN        NaN
# 1345              tests/findMovementsController.spec.ts       NaN        NaN
# 1346                 tests/findMovementsUseCase.spec.ts       NaN        NaN
# 1347               tests/getEquipmentController.spec.ts       NaN        NaN
# 1348                  tests/getEquipmentUseCase.spec.ts       NaN        NaN
# 1349      tests/update-order-service-controller.spec.ts       NaN        NaN
# 1350                 tests/update-order-service.spec.ts       NaN        NaN
# 900                                        src/adapters         2          3
# 901                         src/presentation/controller        24         79
# 902                           src/factories/controllers        12         12
# 903                   src/useCases/create-order-service        10         19
# 904                        src/useCases/createEquipment        10         54
# 905                         src/useCases/createMovement        12         32
# 906                                              src/db        46         50
# 907                         src/useCases/deleteMovement         7         12
# 908                                 src/domain/entities         0          0
# 909                                     src/db/entities        28         28
# 910                  src/domain/entities/equipamentEnum         0          0
# 911                       src/db/repositories/equipment         5          7
# 912                            src/repository/equipment         0          0
# 913                             src/presentation/errors         6          7
# 914            src/useCases/create-order-service/errors         8          8
# 915                                       src/factories        24         24
# 916                     src/useCases/find-order-service         3          4
# 917                        src/useCases/findAcquisition         3          4
# 918                              src/useCases/findBrand         3          4
# 919                          src/useCases/findMovements         4         12
# 920                       src/useCases/findOneEquipment         3          4
# 921                               src/useCases/findUnit         3          4
# 922                               src/useCases/FindUnit         3          4
# 923                           src/useCases/getEquipment         2          8
# 924                            src/presentation/helpers         6          8
# 925                         src/db/repositories/history         2          2
# 926                              src/repository/history         0          0
# 927                                     src/middlewares         1          2
# 928                                   src/db/migrations         5          5
# 929                   src/db/repositories/order-service         4          4
# 930                        src/repository/order-service         2          2
# 931                                    src/presentation        37         95
# 932                             src/repository/protocol         0          0
# 933                               src/useCases/protocol         0          0
# 934                          src/presentation/protocols         1          1
# 935                                 src/db/repositories        13         16
# 936                                      src/repository        28         37
# 937                src/domain/entities/serviceOrderEnum         0          0
# 938                                                 src       208        395
# 939                                               tests       NaN        NaN
# 940                src/domain/entities/type-action-enum         0          0
# 941                            src/db/repositories/unit         2          3
# 942                                 src/repository/unit         0          0
# 943                   src/useCases/update-order-service         3         18
# 944                                        src/useCases        66        179
# 945                              src/factories/useCases        12         12
# 946              tests/create-equipment-usecase.spec.ts       NaN        NaN
# 947       tests/create-order-service-controller.spec.ts       NaN        NaN
# 948                  tests/create-order-service.spec.ts       NaN        NaN
# 949             tests/createEquipmentController.spec.ts       NaN        NaN
# 950              tests/createMovementController.spec.ts       NaN        NaN
# 951                 tests/createMovementUseCase.spec.ts       NaN        NaN
# 952              tests/deleteMovementController.spec.ts       NaN        NaN
# 953                 tests/deleteMovementUseCase.spec.ts       NaN        NaN
# 954                   tests/find-orders-service.spec.ts       NaN        NaN
# 955                tests/findAllUnitsController.spec.ts       NaN        NaN
# 956               tests/findMovementsController.spec.ts       NaN        NaN
# 957                  tests/findMovementsUseCase.spec.ts       NaN        NaN
# 958                tests/getEquipmentController.spec.ts       NaN        NaN
# 959                   tests/getEquipmentUseCase.spec.ts       NaN        NaN
# 960       tests/update-order-service-controller.spec.ts       NaN        NaN
# 961                  tests/update-order-service.spec.ts       NaN        NaN
# 124                                        src/adapters         2          3
# 125                         src/presentation/controller        24         79
# 126                           src/factories/controllers        12         12
# 127                   src/useCases/create-order-service        10         19
# 128                        src/useCases/createEquipment        10         54
# 129                         src/useCases/createMovement        12         32
# 130                                              src/db        46         50
# 131                         src/useCases/deleteMovement         7         12
# 132                                 src/domain/entities         0          0
# 133                                     src/db/entities        28         28
# 134                  src/domain/entities/equipamentEnum         0          0
# 135                       src/db/repositories/equipment         5          7
# 136                            src/repository/equipment         0          0
# 137                             src/presentation/errors         6          7
# 138            src/useCases/create-order-service/errors         8          8
# 139                                       src/factories        24         24
# 140                     src/useCases/find-order-service         3          4
# 141                        src/useCases/findAcquisition         3          4
# 142                              src/useCases/findBrand         3          4
# 143                          src/useCases/findMovements         4         12
# 144                       src/useCases/findOneEquipment         3          4
# 145                               src/useCases/findUnit         3          4
# 146                               src/useCases/FindUnit         3          4
# 147                           src/useCases/getEquipment         2          8
# 148                            src/presentation/helpers         6          8
# 149                         src/db/repositories/history         2          2
# 150                              src/repository/history         0          0
# 151                                     src/middlewares         1          2
# 152                                   src/db/migrations         5          5
# 153                   src/db/repositories/order-service         4          4
# 154                        src/repository/order-service         2          2
# 155                                    src/presentation        37         95
# 156                             src/repository/protocol         0          0
# 157                               src/useCases/protocol         0          0
# 158                          src/presentation/protocols         1          1
# 159                                 src/db/repositories        13         16
# 160                                      src/repository        28         37
# 161                src/domain/entities/serviceOrderEnum         0          0
# 162                                                 src       208        395
# 163                                               tests       NaN        NaN
# 164                src/domain/entities/type-action-enum         0          0
# 165                            src/db/repositories/unit         2          3
# 166                                 src/repository/unit         0          0
# 167                   src/useCases/update-order-service         3         18
# 168                                        src/useCases        66        179
# 169                              src/factories/useCases        12         12
# 170              tests/create-equipment-usecase.spec.ts       NaN        NaN
# 171       tests/create-order-service-controller.spec.ts       NaN        NaN
# 172                  tests/create-order-service.spec.ts       NaN        NaN
# 173             tests/createEquipmentController.spec.ts       NaN        NaN
# 174              tests/createMovementController.spec.ts       NaN        NaN
# 175                 tests/createMovementUseCase.spec.ts       NaN        NaN
# 176              tests/deleteMovementController.spec.ts       NaN        NaN
# 177                 tests/deleteMovementUseCase.spec.ts       NaN        NaN
# 178                   tests/find-orders-service.spec.ts       NaN        NaN
# 179                tests/findAllUnitsController.spec.ts       NaN        NaN
# 180               tests/findMovementsController.spec.ts       NaN        NaN
# 181                  tests/findMovementsUseCase.spec.ts       NaN        NaN
# 182                tests/getEquipmentController.spec.ts       NaN        NaN
# 183                   tests/getEquipmentUseCase.spec.ts       NaN        NaN
# 184       tests/update-order-service-controller.spec.ts       NaN        NaN
# 185                  tests/update-order-service.spec.ts       NaN        NaN
# 62                                         src/adapters         2          3
# 63                          src/presentation/controller        24         79
# 64                            src/factories/controllers        12         12
# 65                    src/useCases/create-order-service        10         19
# 66                         src/useCases/createEquipment        10         54
# 67                          src/useCases/createMovement        12         32
# 68                                               src/db        46         50
# 69                          src/useCases/deleteMovement         7         12
# 70                                  src/domain/entities         0          0
# 71                                      src/db/entities        28         28
# 72                   src/domain/entities/equipamentEnum         0          0
# 73                        src/db/repositories/equipment         5          7
# 74                             src/repository/equipment         0          0
# 75                              src/presentation/errors         6          7
# 76             src/useCases/create-order-service/errors         8          8
# 77                                        src/factories        24         24
# 78                      src/useCases/find-order-service         3          4
# 79                         src/useCases/findAcquisition         3          4
# 80                               src/useCases/findBrand         3          4
# 81                           src/useCases/findMovements         4         12
# 82                        src/useCases/findOneEquipment         3          4
# 83                                src/useCases/findUnit         3          4
# 84                                src/useCases/FindUnit         3          4
# 85                            src/useCases/getEquipment         2          8
# 86                             src/presentation/helpers         6          8
# 87                          src/db/repositories/history         2          2
# 88                               src/repository/history         0          0
# 89                                      src/middlewares         1          2
# 90                                    src/db/migrations         5          5
# 91                    src/db/repositories/order-service         4          4
# 92                         src/repository/order-service         2          2
# 93                                     src/presentation        37         95
# 94                              src/repository/protocol         0          0
# 95                                src/useCases/protocol         0          0
# 96                           src/presentation/protocols         1          1
# 97                                  src/db/repositories        13         16
# 98                                       src/repository        28         37
# 99                 src/domain/entities/serviceOrderEnum         0          0
# 100                                                 src       208        395
# 101                                               tests       NaN        NaN
# 102                src/domain/entities/type-action-enum         0          0
# 103                            src/db/repositories/unit         2          3
# 104                                 src/repository/unit         0          0
# 105                   src/useCases/update-order-service         3         18
# 106                                        src/useCases        66        179
# 107                              src/factories/useCases        12         12
# 108              tests/create-equipment-usecase.spec.ts       NaN        NaN
# 109       tests/create-order-service-controller.spec.ts       NaN        NaN
# 110                  tests/create-order-service.spec.ts       NaN        NaN
# 111             tests/createEquipmentController.spec.ts       NaN        NaN
# 112              tests/createMovementController.spec.ts       NaN        NaN
# 113                 tests/createMovementUseCase.spec.ts       NaN        NaN
# 114              tests/deleteMovementController.spec.ts       NaN        NaN
# 115                 tests/deleteMovementUseCase.spec.ts       NaN        NaN
# 116                   tests/find-orders-service.spec.ts       NaN        NaN
# 117                tests/findAllUnitsController.spec.ts       NaN        NaN
# 118               tests/findMovementsController.spec.ts       NaN        NaN
# 119                  tests/findMovementsUseCase.spec.ts       NaN        NaN
# 120                tests/getEquipmentController.spec.ts       NaN        NaN
# 121                   tests/getEquipmentUseCase.spec.ts       NaN        NaN
# 122       tests/update-order-service-controller.spec.ts       NaN        NaN
# 123                  tests/update-order-service.spec.ts       NaN        NaN
# 790                                        src/adapters         2          3
# 791                         src/presentation/controller        24         79
# 792                           src/factories/controllers        12         12
# 793                   src/useCases/create-order-service        10         19
# 794                        src/useCases/createEquipment        10         54
# 795                         src/useCases/createMovement        12         32
# 796                                              src/db        46         50
# 797                         src/useCases/deleteMovement         7         12
# 798                                 src/domain/entities         0          0
# 799                                     src/db/entities        28         28
# 800                  src/domain/entities/equipamentEnum         0          0
# 801                       src/db/repositories/equipment         5          7
# 802                            src/repository/equipment         0          0
# 803                             src/presentation/errors         6          7
# 804            src/useCases/create-order-service/errors         8          8
# 805                                       src/factories        24         24
# 806                     src/useCases/find-order-service         3          4
# 807                        src/useCases/findAcquisition         3          4
# 808                              src/useCases/findBrand         3          4
# 809                          src/useCases/findMovements         4         12
# 810                       src/useCases/findOneEquipment         3          4
# 811                               src/useCases/findUnit         3          4
# 812                               src/useCases/FindUnit         3          4
# 813                           src/useCases/getEquipment         2          8
# 814                            src/presentation/helpers         6          8
# 815                         src/db/repositories/history         2          2
# 816                              src/repository/history         0          0
# 817                                     src/middlewares         1          2
# 818                                   src/db/migrations         5          5
# 819                   src/db/repositories/order-service         4          4
# 820                        src/repository/order-service         2          2
# 821                                    src/presentation        37         95
# 822                             src/repository/protocol         0          0
# 823                               src/useCases/protocol         0          0
# 824                          src/presentation/protocols         1          1
# 825                                 src/db/repositories        13         16
# 826                                      src/repository        28         37
# 827                src/domain/entities/serviceOrderEnum         0          0
# 828                                                 src       208        395
# 829                                               tests       NaN        NaN
# 830                src/domain/entities/type-action-enum         0          0
# 831                            src/db/repositories/unit         2          3
# 832                                 src/repository/unit         0          0
# 833                   src/useCases/update-order-service         3         18
# 834                                        src/useCases        66        179
# 835                              src/factories/useCases        12         12
# 836              tests/create-equipment-usecase.spec.ts       NaN        NaN
# 837       tests/create-order-service-controller.spec.ts       NaN        NaN
# 838                  tests/create-order-service.spec.ts       NaN        NaN
# 839             tests/createEquipmentController.spec.ts       NaN        NaN
# 840              tests/createMovementController.spec.ts       NaN        NaN
# 841                 tests/createMovementUseCase.spec.ts       NaN        NaN
# 842              tests/deleteMovementController.spec.ts       NaN        NaN
# 843                 tests/deleteMovementUseCase.spec.ts       NaN        NaN
# 844                   tests/find-orders-service.spec.ts       NaN        NaN
# 845                tests/findAllUnitsController.spec.ts       NaN        NaN
# 846               tests/findMovementsController.spec.ts       NaN        NaN
# 847                  tests/findMovementsUseCase.spec.ts       NaN        NaN
# 848                tests/getEquipmentController.spec.ts       NaN        NaN
# 849                   tests/getEquipmentUseCase.spec.ts       NaN        NaN
# 850       tests/update-order-service-controller.spec.ts       NaN        NaN
# 851                  tests/update-order-service.spec.ts       NaN        NaN
# 248                                        src/adapters         2          3
# 249                         src/presentation/controller        24         79
# 250                           src/factories/controllers        12         12
# 251                   src/useCases/create-order-service        10         19
# 252                        src/useCases/createEquipment        10         54
# 253                         src/useCases/createMovement        12         32
# 254                                              src/db        46         50
# 255                         src/useCases/deleteMovement         7         12
# 256                                 src/domain/entities         0          0
# 257                                     src/db/entities        28         28
# 258                  src/domain/entities/equipamentEnum         0          0
# 259                       src/db/repositories/equipment         5          7
# 260                            src/repository/equipment         0          0
# 261                             src/presentation/errors         6          7
# 262            src/useCases/create-order-service/errors         8          8
# 263                                       src/factories        24         24
# 264                     src/useCases/find-order-service         3          4
# 265                        src/useCases/findAcquisition         3          4
# 266                              src/useCases/findBrand         3          4
# 267                          src/useCases/findMovements         4         12
# 268                       src/useCases/findOneEquipment         3          4
# 269                               src/useCases/findUnit         3          4
# 270                               src/useCases/FindUnit         3          4
# 271                           src/useCases/getEquipment         2          8
# 272                            src/presentation/helpers         6          8
# 273                         src/db/repositories/history         2          2
# 274                              src/repository/history         0          0
# 275                                     src/middlewares         1          2
# 276                                   src/db/migrations         5          5
# 277                   src/db/repositories/order-service         4          4
# 278                        src/repository/order-service         2          2
# 279                                    src/presentation        37         95
# 280                             src/repository/protocol         0          0
# 281                               src/useCases/protocol         0          0
# 282                          src/presentation/protocols         1          1
# 283                                 src/db/repositories        13         16
# 284                                      src/repository        28         37
# 285                src/domain/entities/serviceOrderEnum         0          0
# 286                                                 src       208        395
# 287                                               tests       NaN        NaN
# 288                src/domain/entities/type-action-enum         0          0
# ...
# 1197  05-17-2023-22-22-51   v0.1.0
# 1198  05-17-2023-22-22-51   v0.1.0
# 1199  05-17-2023-22-22-51   v0.1.0
